# %%
import pandas as pd

# %%
dataset = pd.read_csv('../GeneralAI/tele_labelling/Abou_labeling.csv')

# %%
dataset
# Out:
#                            date  \
# 0     2022-07-27 07:39:47+00:00
# 1     2022-07-05 05:24:47+00:00
# 2     2021-06-02 12:51:06+00:00
# 3     2020-04-10 10:01:01+00:00
# 4     2021-03-18 18:18:23+00:00
# ...                         ...
# 3739  2018-10-01 08:02:33+00:00
# 3740  2021-04-08 13:33:55+00:00
# 3741  2020-06-24 06:18:06+00:00
# 3742  2022-07-13 20:38:35+00:00
# 3743  2021-10-13 14:19:37+00:00
#
#                                                 comment platform
# 0     Kama unatumia @zanteltz usiwe na hofu yeyote.....  Twitter
# 1     @OriginoZee17 Huku tigo hiyo 2000 yako utaenda...  Twitter
# 2     @VodacomTanzania Nineacha kutumia MPESA kwa sa...  Twitter
# 3     #UjanjaNi kufanya kazi kwa kasi ya 4G.\nHuna h...  Twitter
# 4                @Mshambaflan Leo Tigo 4G naiona byeeee  Twitter
# ...                                                 ...      ...
# 3739  @Tigo_TZ Kwa hiyo ili mjue kama internet yenu ...  Twitter
# ...

# %%
#hapa tunaongeza column 'sentiment', 'topic', 'intent' kwa data ''

i = 0
while(i<3745):
    dataset['sentiment'] = ''
    dataset['topic'] = ''
    dataset['intent'] = ''
    i += 1

# %%
dataset.tail()
# Out:
#                            date  \
# 3739  2018-10-01 08:02:33+00:00
# 3740  2021-04-08 13:33:55+00:00
# 3741  2020-06-24 06:18:06+00:00
# 3742  2022-07-13 20:38:35+00:00
# 3743  2021-10-13 14:19:37+00:00
#
#                                                 comment platform sentiment  \
# 3739  @Tigo_TZ Kwa hiyo ili mjue kama internet yenu ...  Twitter
# 3740  @Tigo_TZ Hapana nyie mnakamua sana wateja wenu...  Twitter
# 3741  @DosaRahma @isaya_lameck @LusakoWaKwanza @Waku...  Twitter
# 3742  kwa neighbor naskia "beb songesha panty side m...  Twitter
# 3743  @lenardjnr,Unaweza kumuunga mwanachama wa mtan...  Twitter
#
#      topic intent
# 3739
# 3740
# 3741
# 3742
# 3743
